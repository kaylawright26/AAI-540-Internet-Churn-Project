# %% [markdown]
# <a href="https://colab.research.google.com/github/kaylawright26/AAI-540-Internet-Churn-Project/blob/main/Merge_test_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv('/content/gdrive/MyDrive/test_unscaled (1).csv')

# %%
df2=pd.read_csv('/content/gdrive/MyDrive/predictions.csv')

# %%
df.shape
# Out:
# (7227, 13)

# %%
df2.shape
# Out:
# (7227, 2)

# %%
df
# Out:
#       Unnamed: 0  subscription_age  bill_avg  service_failure_count  \
# 0            605              5.65      36.0                    0.0
# 1          24663              5.72      26.0                    0.0
# 2          58208              1.17      27.0                    0.0
# 3          27004              1.01      21.0                    0.0
# 4          16987              0.85      18.0                    0.0
# ...          ...               ...       ...                    ...
# 7222       47231              2.44      18.0                    1.0
# 7223         296             11.92      22.0                    0.0
# 7224        5724              4.44      32.0                    0.0
# 7225       62532              0.85      21.0                    1.0
# 7226       16631              3.67      23.0                    0.0
#
#       download_avg  upload_avg  download_over_limit  is_tv_subscriber  \
# 0              0.0         0.0                  0.0                 1
# 1             30.5         2.9                  0.0                 1
# 2              7.8         0.6                  0.0                 1
# 3             14.9         1.7                  0.0                 1
# 4              0.0         0.0                  0.0                 0
# ...            ...         ...                  ...               ...
# 7222          19.7         1.9                  0.0                 1
# 7223          64.1         7.1                  0.0                 1
# 7224          16.1         1.1                  1.0                 1
# 7225          14.6         1.2                  0.0                 1
# 7226           2.5         0.1                  0.0                 1
#
#       is_movie_package_subscriber  remaining_contract_0-1_years  \
# 0                               0                             1
# 1                               1                             0
# 2                               1                             0
# 3                               0                             0
# 4                               0                             1
# ...                           ...                           ...
# 7222                            0                             0
# 7223                            0                             1
# 7224                            1                             0
# 7225                            0                             0
# 7226                            0                             0
#
#       remaining_contract_1-2_years  remaining_contract_2-3_years  \
# 0                                0                             0
# 1                                1                             0
# 2                                0                             0
# 3                                0                             0
# 4                                0                             0
# ...                            ...                           ...
# 7222                             1                             0
# 7223                             0                             0
# 7224                             0                             0
# 7225                             0                             0
# 7226                             0                             0
#
#       remaining_contract_no_contract
# 0                                  0
# 1                                  0
# 2                                  1
# 3                                  1
# 4                                  0
# ...                              ...
# 7222                               0
# 7223                               0
# 7224                               1
# 7225                               1
# 7226                               1
#
# [7227 rows x 13 columns]

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df2.columns=['pred']
df2.shape
# Out:
# (7226, 1)

# %%
df2.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df2
# Out:
#       pred
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
# ...    ...
# 7222     0
# 7223     0
# 7224     1
# 7225     1
# 7226     1
#
# [7227 rows x 1 columns]

# %%
df3=pd.merge(df,df2)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-57-e65c2c286593> in <cell line: 1>()
# ----> 1 df3=pd.merge(df,df2)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     683             warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
#     684
# --> 685         self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     686
#     687         cross_col = None
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _validate_left_right_on(self, left_on, right_on)
#    1432                 common_cols = left_cols.intersection(right_cols)
#    1433                 if len(common_cols) == 0:
# -> 1434                     raise MergeError(
#    1435                         "No common columns to perform merge on. "
#    1436                         f"Merge options: left_on={left_on}, "
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
df['pred']=df2['pred'].copy()

# %%
df['pred'] = df['pred'].apply(lambda x: 0 if x < 0.5 else 1)
df
# Out:
#       subscription_age  bill_avg  service_failure_count  download_avg  \
# 0                 5.65      36.0                    0.0           0.0
# 1                 5.72      26.0                    0.0          30.5
# 2                 1.17      27.0                    0.0           7.8
# 3                 1.01      21.0                    0.0          14.9
# 4                 0.85      18.0                    0.0           0.0
# ...                ...       ...                    ...           ...
# 7222              2.44      18.0                    1.0          19.7
# 7223             11.92      22.0                    0.0          64.1
# 7224              4.44      32.0                    0.0          16.1
# 7225              0.85      21.0                    1.0          14.6
# 7226              3.67      23.0                    0.0           2.5
#
#       upload_avg  download_over_limit  is_tv_subscriber  \
# 0            0.0                  0.0                 1
# 1            2.9                  0.0                 1
# 2            0.6                  0.0                 1
# 3            1.7                  0.0                 1
# 4            0.0                  0.0                 0
# ...          ...                  ...               ...
# 7222         1.9                  0.0                 1
# 7223         7.1                  0.0                 1
# 7224         1.1                  1.0                 1
# 7225         1.2                  0.0                 1
# 7226         0.1                  0.0                 1
#
#       is_movie_package_subscriber  remaining_contract_0-1_years  \
# 0                               0                             1
# 1                               1                             0
# 2                               1                             0
# 3                               0                             0
# 4                               0                             1
# ...                           ...                           ...
# 7222                            0                             0
# 7223                            0                             1
# 7224                            1                             0
# 7225                            0                             0
# 7226                            0                             0
#
#       remaining_contract_1-2_years  remaining_contract_2-3_years  \
# 0                                0                             0
# 1                                1                             0
# 2                                0                             0
# 3                                0                             0
# 4                                0                             0
# ...                            ...                           ...
# 7222                             1                             0
# 7223                             0                             0
# 7224                             0                             0
# 7225                             0                             0
# 7226                             0                             0
#
#       remaining_contract_no_contract  pred
# 0                                  0     0
# 1                                  0     1
# 2                                  1     1
# 3                                  1     1
# 4                                  0     0
# ...                              ...   ...
# 7222                               0     0
# 7223                               0     1
# 7224                               1     1
# 7225                               1     1
# 7226                               1     1
#
# [7227 rows x 13 columns]

# %%
df
# Out:
#       subscription_age  bill_avg  service_failure_count  download_avg  \
# 0                 5.65      36.0                    0.0           0.0
# 1                 5.72      26.0                    0.0          30.5
# 2                 1.17      27.0                    0.0           7.8
# 3                 1.01      21.0                    0.0          14.9
# 4                 0.85      18.0                    0.0           0.0
# ...                ...       ...                    ...           ...
# 7222              2.44      18.0                    1.0          19.7
# 7223             11.92      22.0                    0.0          64.1
# 7224              4.44      32.0                    0.0          16.1
# 7225              0.85      21.0                    1.0          14.6
# 7226              3.67      23.0                    0.0           2.5
#
#       upload_avg  download_over_limit  is_tv_subscriber  \
# 0            0.0                  0.0                 1
# 1            2.9                  0.0                 1
# 2            0.6                  0.0                 1
# 3            1.7                  0.0                 1
# 4            0.0                  0.0                 0
# ...          ...                  ...               ...
# 7222         1.9                  0.0                 1
# 7223         7.1                  0.0                 1
# 7224         1.1                  1.0                 1
# 7225         1.2                  0.0                 1
# 7226         0.1                  0.0                 1
#
#       is_movie_package_subscriber  remaining_contract_0-1_years  \
# 0                               0                             1
# 1                               1                             0
# 2                               1                             0
# 3                               0                             0
# 4                               0                             1
# ...                           ...                           ...
# 7222                            0                             0
# 7223                            0                             1
# 7224                            1                             0
# 7225                            0                             0
# 7226                            0                             0
#
#       remaining_contract_1-2_years  remaining_contract_2-3_years  \
# 0                                0                             0
# 1                                1                             0
# 2                                0                             0
# 3                                0                             0
# 4                                0                             0
# ...                            ...                           ...
# 7222                             1                             0
# 7223                             0                             0
# 7224                             0                             0
# 7225                             0                             0
# 7226                             0                             0
#
#       remaining_contract_no_contract  pred
# 0                                  0     1
# 1                                  0     0
# 2                                  1     1
# 3                                  1     1
# 4                                  0     1
# ...                              ...   ...
# 7222                               0     0
# 7223                               0     0
# 7224                               1     1
# 7225                               1     1
# 7226                               1     1
#
# [7227 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# subscription_age                  0
# bill_avg                          0
# service_failure_count             0
# download_avg                      0
# upload_avg                        0
# download_over_limit               0
# is_tv_subscriber                  0
# is_movie_package_subscriber       0
# remaining_contract_0-1_years      0
# remaining_contract_1-2_years      0
# remaining_contract_2-3_years      0
# remaining_contract_no_contract    0
# pred                              0
# dtype: int64

# %%
df.to_csv('/content/gdrive/MyDrive/final_predictions')
